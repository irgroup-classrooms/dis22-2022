# %% [markdown]
# ## imports

# %%
from rai_app import suggests
import string
from functools import lru_cache
import pandas as pd

# %% [markdown]
# ## functions

# %%
def lev_dist(a, b):
    '''
    This function will calculate the levenshtein distance between two input
    strings a and b
    
    params:
        a (String) : The first string you want to compare
        b (String) : The second string you want to compare
        
    returns:
        This function will return the distnace between string a and b.
        
    example:
        a = 'stamp'
        b = 'stomp'
        lev_dist(a,b)
        >> 1.0
    '''
    
    @lru_cache(None)  # for memorization
    def min_dist(s1, s2):

        if s1 == len(a) or s2 == len(b):
            return len(a) - s1 + len(b) - s2

        # no change required
        if a[s1] == b[s2]:
            return min_dist(s1 + 1, s2 + 1)

        return 1 + min(
            min_dist(s1, s2 + 1),      # insert character
            min_dist(s1 + 1, s2),      # delete character
            min_dist(s1 + 1, s2 + 1),  # replace character
        )

    return min_dist(0, 0)

#source: https://towardsdatascience.com/text-similarity-w-levenshtein-distance-in-python-2f7478986e75

# %%
def lev_dist_list(term):
    item = term.split(' ')
    dist = []
    for word in item:
        dist.append(lev_dist('baerbock',word))
    if any(ele < 5 for ele in dist):
        return term
    else:
        return None

# %%
lev_dist('baum','klawum')
# Out:
# 3

# %%
def lev_dist_row(row):
    scores = []
    for root_word in row.root.split():
        for target_word in row.target.split():
            scores.append(lev_dist(root_word, target_word))
    if any(score<3 for score in scores):
        return row.target
    else:
        return 'delete'

# %%
#df_test
#data = {'root':['christian eriksen','christian eriksen'],'target':['christian erikesn baum test','trizion seifokmon der allerechte test']}
#df_fake = pd.DataFrame(data)
#df_fake
#df_test = pd.concat([df_test,df_fake])
#df_test
#df_test.apply(lev_dist_row, axis=1)
# Out:
# 0            christian eriksen aktuell
# 1              christian eriksen alter
# 2               christian eriksen arzt
# 3     christian eriksen aktuelle teams
# 4              christian eriksen agent
# 5             christian eriksen attack
# 6    christian eriksen and simon kjaer
# 7          christian eriksen and covid
# 8     christian eriksen and harry kane
# 9         christian eriksen and family
# 0          christian erikesn baum test
# 1                               delete
# dtype: object

# %% [markdown]
# ## testing

# %%
gd = suggests.get_suggests('baerbock', source='google')
# Out:
# 2022-04-29 12:04:18,300 | 15354 | INFO | logger | google | baerbock
# 2022-04-29 12:04:19,106 | 15354 | INFO | logger | google | baerbock
# 2022-04-29 12:04:19,992 | 15354 | INFO | logger | google | baerbock

# %%
gd['suggests']
# Out:
# ['baerbock außenministerin',
#  'baerbock abgenommen',
#  'baerbock assange',
#  'baerbock amt',
#  'baerbock auto',
#  'baerbock außenpolitik',
#  'baerbock ard',
#  'baerbock an der front',
#  'baerbock ansprache',
#  'baerbock afghanistan',
#  'baerbock beliebtheit',
#  'baerbock buch',
#  'baerbock bademantel',
#  'baerbock bilder',
#  'baerbock bei putin',
#  'baerbock besuch ukraine',
#  'baerbock biografie',
#  'baerbock besuch russland',
#  'baerbock bild',
#  'baerbock beliebt',
#  'baerbock china',
#  'baerbock cv',
#  'baerbock cnn',
#  'baerbock cairo',
#  'baerbock cartoon',
#  'baerbock chemnitz',
#  'baerbock clinton',
#  'baerbock cdu',
#  'baerbock che guevara',
#  'baerbock comic']

# %%
g['suggests']
# Out:
# ['baerbock außenministerin',
#  'baerbock abgenommen',
#  'baerbock assange',
#  'baerbock amt',
#  'baerbock auto',
#  'baerbock außenpolitik',
#  'baerbock ard',
#  'baerbock an der front',
#  'baerbock ansprache',
#  'baerbock afghanistan',
#  'baerbock beliebtheit',
#  'baerbock buch',
#  'baerbock bademantel',
#  'baerbock bilder',
#  'baerbock bei putin',
#  'baerbock besuch ukraine',
#  'baerbock biografie',
#  'baerbock besuch russland',
#  'baerbock bild',
#  'baerbock beliebt',
#  'baerbock china',
#  'baerbock cv',
#  'baerbock cnn',
#  'baerbock cairo',
#  'baerbock cartoon',
#  'baerbock chemnitz',
#  'baerbock clinton',
#  'baerbock cdu',
#  'baerbock che guevara',
#  'baerbock comic']

# %%
bd = suggests.get_suggests('baerbock', source='bing')
# Out:
# 2022-04-29 12:04:45,256 | 15354 | INFO | logger | bing | baerbock
# 2022-04-29 12:04:46,599 | 15354 | INFO | logger | bing | baerbock
# 2022-04-29 12:04:48,071 | 15354 | INFO | logger | bing | baerbock

# %%
bd['suggests']
# Out:
# ['baerbock annalena',
#  'baerbock alter',
#  'baerbock aktuell',
#  'baerbock ausbildung',
#  'baerbock annalena ehemann',
#  'baerbock annalena privat',
#  'baerbock afghanistan',
#  'baerbock anne will',
#  'baerbock buch',
#  'baerbock bilder',
#  'baerbock bosnien',
#  'baerbock bikini',
#  'baerbock beine',
#  'baerbock blinken',
#  'baerbock balkan',
#  'baerbock beruf',
#  'baerbock china',
#  'baerbock cv',
#  'baerbock cnn',
#  'baerbock corona bonus',
#  'baerbock corona',
#  'baerbock cartoon',
#  'baerbock chancen',
#  'baerbock china politik']

# %%
b['suggests']
# Out:
# ['baerbock annalena',
#  'baerbock alter',
#  'baerbock aktuell',
#  'baerbock ausbildung',
#  'baerbock annalena ehemann',
#  'baerbock annalena privat',
#  'baerbock afghanistan',
#  'baerbock anne will',
#  'baerbock buch',
#  'baerbock bilder',
#  'baerbock bikini',
#  'baerbock bei putin',
#  'baerbock beine',
#  'baerbock blinken',
#  'baerbock balkan',
#  'baerbock beruf',
#  'baerbock china',
#  'baerbock cv',
#  'baerbock corona bonus',
#  'baerbock corona',
#  'baerbock cartoon',
#  'baerbock chancen',
#  'baerbock comic',
#  'baerbock corona hilfe',
#  'baerbock droht russland',
#  'baerbock dumme zitate',
#  'baerbock dienstwagen',
#  'baerbock droht',
#  'baerbock droht putin',
#  'baerbock doktorarbeit',
#  'baerbock dissertation',
#  'baerbock donbass',
#  'baerbock englisch',
#  'baerbock ehemann',
#  'baerbock english',
#  'baerbock eltern',
#  'baerbock englisch video',
#  'baerbock email',
#  'baerbock englisch youtube',
#  'baerbock eiffelturm',
#  'baerbock familie',
#  'baerbock facebook',
#  'baerbock feet',
#  'baerbock fotos',
#  'baerbock fauxpas',
#  'baerbock frisur',
#  'baerbock pressefreiheit',
#  'baerbock fehler',
#  'baerbock gruene',
#  'baerbock greenpeace',
#  'baerbock gehalt',
#  'baerbock g7',
#  'baerbock germany',
#  'baerbock gestern',
#  'baerbock gewicht',
#  'baerbock gegen putin',
#  'baerbock habeck',
#  'baerbock helm',
#  'baerbock heute',
#  'baerbock haustiere',
#  'baerbock homepage',
#  'baerbock hunde',
#  'baerbock herkunft',
#  'baerbock high heels',
#  'baerbock israel',
#  'baerbock in moskau',
#  'baerbock in polen',
#  'baerbock in russland',
#  'baerbock in paris',
#  'baerbock interview',
#  'baerbock impfpflicht',
#  'baerbock in israel',
#  'baerbock jung',
#  'baerbock jetzt',
#  'baerbock junge dame',
#  'baerbock jeans',
#  'baerbock juristin',
#  'baerbock jugendfoto',
#  'baerbock jordanien',
#  'baerbock junge welt',
#  'baerbock kobold',
#  'baerbock kinder',
#  'baerbock kritik',
#  'baerbock kosovo',
#  'baerbock kontakt',
#  'baerbock kleider',
#  'baerbock kleidung',
#  'baerbock kiew',
#  'baerbock lebenslauf',
#  'baerbock lawrow',
#  'baerbock live',
#  'baerbock lustig',
#  'baerbock lindner',
#  'baerbock laschet',
#  'baerbock lanz',
#  'baerbock laschet scholz',
#  'baerbock mann',
#  'baerbock moskau',
#  'baerbock marokko',
#  'baerbock merz',
#  'baerbock morgan',
#  'baerbock mode',
#  'baerbock meme',
#  'baerbock mantel moskau',
#  'baerbock n wort',
#  'baerbock nicht neutral',
#  'baerbock nord stream 2',
#  'baerbock n-wort',
#  'baerbock n word',
#  'baerbock n',
#  'baerbock nato',
#  'baerbock news heute',
#  'baerbock ostkokaine',
#  'baerbock oder habeck',
#  'baerbock olympia',
#  'baerbock outfit',
#  'baerbock oderbruch',
#  'baerbock oberweite',
#  'baerbock oberstaufen',
#  'baerbock ohrringe',
#  'baerbock paris',
#  'baerbock plagiat',
#  'baerbock polen',
#  'baerbock putin',
#  'baerbock privat',
#  'baerbock pressefreiheit',
#  'baerbock peinlich',
#  'baerbock pressekonferenz',
#  'baerbock quellen',
#  'baerbock iq',
#  'baerbock eqs',
#  'baerbock greenpeace',
#  'baerbock gehalt',
#  'baerbock annalena',
#  'baerbock china',
#  'baerbock gestern',
#  'baerbock russland',
#  'baerbock rede',
#  'baerbock rede und',
#  'baerbock rede englisch',
#  'baerbock rede uno',
#  'baerbock rede heute',
#  'baerbock rede russland',
#  'baerbock rede bundestag',
#  'baerbock swift',
#  'baerbock serbien',
#  'baerbock studium',
#  'baerbock skandale',
#  'baerbock strache',
#  'baerbock sprachfehler',
#  'baerbock song',
#  'baerbock spricht englisch',
#  'baerbock twitter',
#  'baerbock trampolin',
#  'baerbock termine',
#  'baerbock taz',
#  'baerbock trampolinspringen',
#  'baerbock tagesschau',
#  'baerbock trampolin video',
#  'baerbock triell',
#  'baerbock un rede',
#  'baerbock ukraine',
#  'baerbock usa',
#  'baerbock uno',
#  'baerbock und',
#  'baerbock und habeck',
#  'baerbock ukraine-krise',
#  'baerbock umfragewerte',
#  'baerbock vita',
#  'baerbock versprecher',
#  'baerbock video',
#  'baerbock versagt',
#  'baerbock verspricht sich',
#  'baerbock vor der uno',
#  'baerbock vor un',
#  'baerbock vereidigung',
#  'baerbock wikipedia',
#  'baerbock witwenrente',
#  'baerbock witze',
#  'baerbock warschau',
#  'baerbock welt',
#  'baerbock witwenrente abschaffen',
#  'baerbock wohnort',
#  'baerbock wahlkreis',
#  'xbox',
#  'xfinity',
#  'xpo',
#  'xrp',
#  'x22',
#  'xcel',
#  'xom',
#  'xmas',
#  'baerbock youtube',
#  'baerbock yad vashem',
#  'baerbock young global leaders',
#  'baerbock young leader',
#  'annalena baerbock youtube',
#  'baerbock wang yi',
#  'annalena baerbock englisch youtube',
#  'youtube baerbock englisch',
#  'baerbock zitate',
#  'baerbock zum russischen angriff',
#  'baerbock zug',
#  'baerbock zu ukraine',
#  'baerbock zdf',
#  'baerbock zur witwenrente',
#  'baerbock zeit',
#  'baerbock zustimmung']

# %%
tree = suggests.get_suggests_tree('baerbock', source='bing', max_depth=1)
# Out:
# 2022-07-08 16:09:30,965 | 2156 | INFO | rai_app.suggests.logger | bing | baerbock
# 2022-07-08 16:09:31,695 | 2156 | INFO | rai_app.suggests.logger | bing | baerbock
# 2022-07-08 16:09:32,508 | 2156 | INFO | rai_app.suggests.logger | bing | baerbock
# 2022-07-08 16:09:32,957 | 2156 | INFO | rai_app.suggests.logger | bing | baerbock annalena
# 2022-07-08 16:09:33,719 | 2156 | INFO | rai_app.suggests.logger | bing | baerbock annalena
# 2022-07-08 16:09:34,434 | 2156 | INFO | rai_app.suggests.logger | bing | baerbock annalena
# 2022-07-08 16:09:35,115 | 2156 | INFO | rai_app.suggests.logger | bing | baerbock außenministerin
# 2022-07-08 16:09:35,824 | 2156 | INFO | rai_app.suggests.logger | bing | baerbock außenministerin
# 2022-07-08 16:09:36,318 | 2156 | INFO | rai_app.suggests.logger | bing | baerbock außenministerin
# 2022-07-08 16:09:36,891 | 2156 | INFO | rai_app.suggests.logger | bing | baerbock alter
# 2022-07-08 16:09:37,525 | 2156 | INFO | rai_app.suggests.logger | bing | baerbock alter
# 2022-07-08 16:09:38,297 | 2156 | INFO | rai_app.suggests.logger | bing | baerbock alter
# 2022-07-08 16:09:38,747 | 2156 | INFO | rai_app.suggests.logger | bing | baerbock aktuell
# 2022-07-08 16:09:39,173 | 2156 | INFO | rai_app.suggests.logger | bing | baerbock aktuell
# 2022-07-08 16:09:39,715 | 2156 | INFO | rai_app.suggests.logger | bing | baerbock aktuell
# 2022-07-08 16:09:40,423 | 2156 | INFO | rai_app.suggests.logger | bing | baerbock annalena lebenslauf
# 2022-07-08 16:09:41,101 | 2156 | INFO | rai_app.suggests.logger | bing | baerbock annalena lebenslauf
# 2022-07-08 16:09:41,668 | 2156 | INFO | rai_app.suggests.logger | bing | baerbock annalena lebenslauf
# 2022-07-08 16:09:42,495 | 2156 | INFO | rai_app.suggests.logger | bing | baerbock assange
# 2022-07-08 16:09:43,159 | 2156 | INFO | rai_app.suggests.logger | bing | baerbock assange
# 2022-07-08 16:09:43,795 | 2156 | INFO | rai_app.suggests.logger | bing | baerbock assange
# 2022-07-08 16:09:44,260 | 2156 | INFO | rai_app.suggests.logger | bing | baerbock annalena privat
# 2022-07-08 16:09:44,854 | 2156 | INFO | rai_app.suggests.logger | bing | baerbock annalena privat
# 2022-07-08 16:09:45,351 | 2156 | INFO | rai_app.suggests.logger | bing | baerbock annalena privat
# 2022-07-08 16:09:45,973 | 2156 | INFO | rai_app.suggests.logger | bing | baerbock ausbildung
# 2022-07-08 16:09:46,707 | 2156 | INFO | rai_app.suggests.logger | bing | baerbock ausbildung
# 2022-07-08 16:09:47,326 | 2156 | INFO | rai_app.suggests.logger | bing | baerbock ausbildung
# 2022-07-08 16:09:48,077 | 2156 | INFO | rai_app.suggests.logger | bing | baerbock bilder
# 2022-07-08 16:09:48,871 | 2156 | INFO | rai_app.suggests.logger | bing | baerbock bilder
# 2022-07-08 16:09:49,509 | 2156 | INFO | rai_app.suggests.logger | bing | baerbock bilder
# 2022-07-08 16:09:50,142 | 2156 | INFO | rai_app.suggests.logger | bing | baerbock buch
# 2022-07-08 16:09:50,944 | 2156 | INFO | rai_app.suggests.logger | bing | baerbock buch
# 2022-07-08 16:09:51,611 | 2156 | INFO | rai_app.suggests.logger | bing | baerbock buch
# 2022-07-08 16:09:52,153 | 2156 | INFO | rai_app.suggests.logger | bing | baerbock buttersäure
# 2022-07-08 16:09:52,865 | 2156 | INFO | rai_app.suggests.logger | bing | baerbock buttersäure
# 2022-07-08 16:09:53,453 | 2156 | INFO | rai_app.suggests.logger | bing | baerbock buttersäure
# 2022-07-08 16:09:54,274 | 2156 | INFO | rai_app.suggests.logger | bing | baerbock beine
# 2022-07-08 16:09:54,803 | 2156 | INFO | rai_app.suggests.logger | bing | baerbock beine
# 2022-07-08 16:09:55,411 | 2156 | INFO | rai_app.suggests.logger | bing | baerbock beine
# 2022-07-08 16:09:55,955 | 2156 | INFO | rai_app.suggests.logger | bing | baerbock betrunken bei anne will
# 2022-07-08 16:09:56,667 | 2156 | INFO | rai_app.suggests.logger | bing | baerbock betrunken bei anne will
# 2022-07-08 16:09:57,349 | 2156 | INFO | rai_app.suggests.logger | bing | baerbock betrunken bei anne will
# 2022-07-08 16:09:58,142 | 2156 | INFO | rai_app.suggests.logger | bing | baerbock bundestag
# 2022-07-08 16:09:58,827 | 2156 | INFO | rai_app.suggests.logger | bing | baerbock bundestag
# 2022-07-08 16:09:59,245 | 2156 | INFO | rai_app.suggests.logger | bing | baerbock bundestag
# 2022-07-08 16:09:59,958 | 2156 | INFO | rai_app.suggests.logger | bing | baerbock beruf
# 2022-07-08 16:10:00,777 | 2156 | INFO | rai_app.suggests.logger | bing | baerbock beruf
# 2022-07-08 16:10:01,565 | 2156 | INFO | rai_app.suggests.logger | bing | baerbock beruf
# 2022-07-08 16:10:02,403 | 2156 | INFO | rai_app.suggests.logger | bing | baerbock balkan
# 2022-07-08 16:10:03,163 | 2156 | INFO | rai_app.suggests.logger | bing | baerbock balkan
# 2022-07-08 16:10:03,863 | 2156 | INFO | rai_app.suggests.logger | bing | baerbock balkan
# 2022-07-08 16:10:04,577 | 2156 | INFO | rai_app.suggests.logger | bing | baerbock corona
# 2022-07-08 16:10:05,010 | 2156 | INFO | rai_app.suggests.logger | bing | baerbock corona
# 2022-07-08 16:10:05,458 | 2156 | INFO | rai_app.suggests.logger | bing | baerbock corona
# 2022-07-08 16:10:05,938 | 2156 | INFO | rai_app.suggests.logger | bing | baerbock china
# 2022-07-08 16:10:06,649 | 2156 | INFO | rai_app.suggests.logger | bing | baerbock china
# 2022-07-08 16:10:07,191 | 2156 | INFO | rai_app.suggests.logger | bing | baerbock china
# 2022-07-08 16:10:07,795 | 2156 | INFO | rai_app.suggests.logger | bing | baerbock cv
# 2022-07-08 16:10:08,369 | 2156 | INFO | rai_app.suggests.logger | bing | baerbock cv
# 2022-07-08 16:10:09,127 | 2156 | INFO | rai_app.suggests.logger | bing | baerbock cv
# 2022-07-08 16:10:09,620 | 2156 | INFO | rai_app.suggests.logger | bing | baerbock corona impfung
# 2022-07-08 16:10:10,332 | 2156 | INFO | rai_app.suggests.logger | bing | baerbock corona impfung
# 2022-07-08 16:10:10,874 | 2156 | INFO | rai_app.suggests.logger | bing | baerbock corona impfung
# 2022-07-08 16:10:11,325 | 2156 | INFO | rai_app.suggests.logger | bing | baerbock cnn
# 2022-07-08 16:10:11,852 | 2156 | INFO | rai_app.suggests.logger | bing | baerbock cnn
# 2022-07-08 16:10:12,372 | 2156 | INFO | rai_app.suggests.logger | bing | baerbock cnn
# 2022-07-08 16:10:13,067 | 2156 | INFO | rai_app.suggests.logger | bing | baerbock corona hilfe
# 2022-07-08 16:10:13,579 | 2156 | INFO | rai_app.suggests.logger | bing | baerbock corona hilfe
# 2022-07-08 16:10:14,294 | 2156 | INFO | rai_app.suggests.logger | bing | baerbock corona hilfe
# 2022-07-08 16:10:14,904 | 2156 | INFO | rai_app.suggests.logger | bing | baerbock cartoon
# 2022-07-08 16:10:15,376 | 2156 | INFO | rai_app.suggests.logger | bing | baerbock cartoon
# 2022-07-08 16:10:15,903 | 2156 | INFO | rai_app.suggests.logger | bing | baerbock cartoon
# 2022-07-08 16:10:16,521 | 2156 | INFO | rai_app.suggests.logger | bing | baerbock co2
# 2022-07-08 16:10:17,262 | 2156 | INFO | rai_app.suggests.logger | bing | baerbock co2
# 2022-07-08 16:10:18,054 | 2156 | INFO | rai_app.suggests.logger | bing | baerbock co2

# %%
df2 = pd.DataFrame(tree)
df2
# Out:
#                                  qry                    datetime source  \
# 0                           baerbock  2022-07-08 14:09:30.395067   bing
# 1                  baerbock annalena  2022-07-08 14:09:32.620720   bing
# 2           baerbock außenministerin  2022-07-08 14:09:34.549337   bing
# 3                     baerbock alter  2022-07-08 14:09:36.464923   bing
# 4                   baerbock aktuell  2022-07-08 14:09:38.409418   bing
# 5       baerbock annalena lebenslauf  2022-07-08 14:09:39.823340   bing
# 6                   baerbock assange  2022-07-08 14:09:41.834980   bing
# 7           baerbock annalena privat  2022-07-08 14:09:43.907234   bing
# 8                baerbock ausbildung  2022-07-08 14:09:45.459834   bing
# 9                    baerbock bilder  2022-07-08 14:09:47.435869   bing
# 10                     baerbock buch  2022-07-08 14:09:49.631284   bing
# 11              baerbock buttersäure  2022-07-08 14:09:51.752332   bing
# 12                    baerbock beine  2022-07-08 14:09:53.579728   bing
# 13  baerbock betrunken bei anne will  2022-07-08 14:09:55.522148   bing
# 14                baerbock bundestag  2022-07-08 14:09:57.470390   bing
# 15                    baerbock beruf  2022-07-08 14:09:59.354394   bing
# 16                   baerbock balkan  2022-07-08 14:10:01.696727   bing
# 17                   baerbock corona  2022-07-08 14:10:04.002570   bing
# 18                    baerbock china  2022-07-08 14:10:05.569626   bing
# 19                       baerbock cv  2022-07-08 14:10:07.300395   bing
# 20           baerbock corona impfung  2022-07-08 14:10:09.278653   bing
# 21                      baerbock cnn  2022-07-08 14:10:10.984109   bing
# 22             baerbock corona hilfe  2022-07-08 14:10:12.478360   bing
# 23                  baerbock cartoon  2022-07-08 14:10:14.403356   bing
# 24                      baerbock co2  2022-07-08 14:10:16.013787   bing
#
#                                                  data  \
# 0   [<ul class="sa_drw" id="sa_ul" role="listbox" ...
# 1   [<ul class="sa_drw" id="sa_ul" role="listbox" ...
# 2   [<ul class="sa_drw" id="sa_ul" role="listbox" ...
# 3   [<ul class="sa_drw" id="sa_ul" role="listbox" ...
# 4   [<ul class="sa_drw" id="sa_ul" role="listbox" ...
# 5   [<ul class="sa_drw" id="sa_ul" role="listbox" ...
# 6   [<ul class="sa_drw" id="sa_ul" role="listbox" ...
# 7   [<ul class="sa_drw" id="sa_ul" role="listbox" ...
# 8   [<ul class="sa_drw" id="sa_ul" role="listbox" ...
# 9   [<ul class="sa_drw" id="sa_ul" role="listbox" ...
# 10  [<ul class="sa_drw" id="sa_ul" role="listbox" ...
# 11  [<ul class="sa_drw" id="sa_ul" role="listbox" ...
# 12  [<ul class="sa_drw" id="sa_ul" role="listbox" ...
# 13  [<ul class="sa_drw" id="sa_ul" role="listbox" ...
# 14  [<ul class="sa_drw" id="sa_ul" role="listbox" ...
# 15  [<ul class="sa_drw" id="sa_ul" role="listbox" ...
# 16  [<ul class="sa_drw" id="sa_ul" role="listbox" ...
# 17  [<ul class="sa_drw" id="sa_ul" role="listbox" ...
# 18  [<ul class="sa_drw" id="sa_ul" role="listbox" ...
# 19  [<ul class="sa_drw" id="sa_ul" role="listbox" ...
# 20  [<ul class="sa_drw" id="sa_ul" role="listbox" ...
# 21  [<ul class="sa_drw" id="sa_ul" role="listbox" ...
# 22  [<ul class="sa_drw" id="sa_ul" role="listbox" ...
# 23  [<ul class="sa_drw" id="sa_ul" role="listbox" ...
# 24  [<ul class="sa_drw" id="sa_ul" role="listbox" ...
#
#                                              suggests self_loops tags  depth  \
# 0   [baerbock annalena, baerbock außenministerin, ...         []   []      0
# 1   [baerbock annalena aktuell, baerbock annalena ...         []   []      1
# 2   [baerbock außenministerin satire, baerbock auß...         []   []      1
# 3   [annalena baerbock alter, annalena baerbock ki...         []   []      1
# 4   [annalena baerbock aktuell, baerbock beliebthe...         []   []      1
# 5   [annalena baerbock lebenslauf und ausbildung, ...         []   []      1
# 6   [annalena baerbock assange, bedroht, berufungs...         []   []      1
# 7   [annalena baerbock privat auto, baerbock annal...         []   []      1
# 8   [baerbock ausbildung abschluss, annalena baerb...         []   []      1
# 9   [annalena baerbock bilder, bilder von annalena...         []   []      1
# 10  [baerbock buch amazon, baerbock buch habeck, a...         []   []      1
# 11  [annalena baerbock buttersäure, baumarkt, buxt...         []   []      1
# 12  [annalena baerbock beine, baerbock bilder bein...         []   []      1
# 13  [annalena baerbock betrunken bei anne will, ba...        [1]   []      1
# 14  [annalena baerbock bundestag, berlin, berät, b...         []   []      1
# 15  [baerbock berufsabschluss, baerbock berufsausb...         []   []      1
# 16  [annalena baerbock balkan, bäckerei, bocholt, ...         []   []      1
# 17  [baerbock corona aktuell, annalena baerbock co...         []   []      1
# 18  [baerbock china taz, annalena baerbock china, ...         []   []      1
# 19  [baerbock cartoon, baerbock cannabis, baerbock...         []   []      1
# 20  [alle hintergründe, anmeldung, auf nummer, arb...         []   []      1
# 21  [baerbock cannabis, baerbock cannabis legalisi...         []   []      1
# 22  [arbeitnehmer, antrag, auszahlung, anlage, abr...         []   []      1
# 23  [annalena baerbock cartoon, bilder, beschreibe...         []   []      1
# 24  [baerbock co2 ausstoß, baerbock co2 haustiere,...         []   []      1
#
#         root crawl_id
# 0   baerbock     None
# 1   baerbock     None
# 2   baerbock     None
# 3   baerbock     None
# 4   baerbock     None
# 5   baerbock     None
# 6   baerbock     None
# 7   baerbock     None
# 8   baerbock     None
# 9   baerbock     None
# 10  baerbock     None
# 11  baerbock     None
# 12  baerbock     None
# 13  baerbock     None
# 14  baerbock     None
# 15  baerbock     None
# 16  baerbock     None
# 17  baerbock     None
# 18  baerbock     None
# 19  baerbock     None
# 20  baerbock     None
# 21  baerbock     None
# 22  baerbock     None
# 23  baerbock     None
# 24  baerbock     None

# %%
df = pd.DataFrame(tree)
df
# Out:
#                                 qry                    datetime  source  \
# 0                          baerbock  2022-07-08 14:05:08.180283  google
# 1                  baerbock assange  2022-07-08 14:05:09.710532  google
# 2          baerbock außenministerin  2022-07-08 14:05:11.553655  google
# 3                   baerbock aachen  2022-07-08 14:05:13.002763  google
# 4               baerbock abgenommen  2022-07-08 14:05:14.831184  google
# 5                  baerbock aktuell  2022-07-08 14:05:16.302184  google
# 6            baerbock außenminister  2022-07-08 14:05:18.122192  google
# 7                   baerbock afrika  2022-07-08 14:05:20.060159  google
# 8               baerbock ausgeladen  2022-07-08 14:05:21.853188  google
# 9                     baerbock auto  2022-07-08 14:05:23.480739  google
# 10               baerbock abschluss  2022-07-08 14:05:25.212600  google
# 11                    baerbock bali  2022-07-08 14:05:27.106573  google
# 12                  baerbock bilder  2022-07-08 14:05:28.531024  google
# 13             baerbock beliebtheit  2022-07-08 14:05:30.606474  google
# 14                 baerbock best of  2022-07-08 14:05:32.351220  google
# 15          baerbock besuch ukraine  2022-07-08 14:05:33.825994  google
# 16                baerbock baltikum  2022-07-08 14:05:35.843324  google
# 17                    baerbock buch  2022-07-08 14:05:37.480230  google
# 18                   baerbock beine  2022-07-08 14:05:39.367502  google
# 19              baerbock bundeswehr  2022-07-08 14:05:40.946752  google
# 20               baerbock bewertung  2022-07-08 14:05:42.765750  google
# 21                  baerbock corona  2022-07-08 14:05:44.550692  google
# 22          baerbock corona aktuell  2022-07-08 14:05:45.964632  google
# 23  baerbock corona wie geht es ihr  2022-07-08 14:05:47.752483  google
# 24          baerbock corona genesen  2022-07-08 14:05:49.537242  google
# 25                   baerbock china  2022-07-08 14:05:51.187014  google
# 26                 baerbock cartoon  2022-07-08 14:05:52.930375  google
# 27    baerbock corona wieder gesund  2022-07-08 14:05:54.834568  google
# 28               baerbock cavusoglu  2022-07-08 14:05:56.861563  google
# 29                      baerbock cv  2022-07-08 14:05:58.790699  google
# 30        baerbock corona infektion  2022-07-08 14:06:00.312248  google
#
#                                                  data  \
# 0   [baerbock a, [[baerbock a<b>ssange</b>, 0, [51...
# 1   [baerbock assange a, [[baerbock assange a<b>us...
# 2   [baerbock außenministerin a, [[baerbock außenm...
# 3   [baerbock aachen a, [[a<b>nnalena </b>baerbock...
# 4   [baerbock abgenommen a, [[a<b>nnalena </b>baer...
# 5   [baerbock aktuell a, [[baerbock<b> heute </b>a...
# 6   [baerbock außenminister a, [[baerbock a<b>ls <...
# 7   [baerbock afrika a, [[a<b>nnalena </b>baerbock...
# 8   [baerbock ausgeladen a, [[baerbock ausgeladen ...
# 9   [baerbock auto a, [[a<b>nnalena </b>baerbock a...
# 10  [baerbock abschluss a, [[baerbock <b>abschluss...
# 11  [baerbock bali a, [[baerbock bali aktuell, 33,...
# 12  [baerbock bilder a, [[baerbock b<b>ei </b>b<b>...
# 13  [baerbock beliebtheit a, [[baerbock beliebthei...
# 14  [baerbock best of a, [[best of a<b>nnalena </b...
# 15  [baerbock besuch ukraine a, [[baerbock besuch ...
# 16  [baerbock baltikum a, [[a<b>nnalena </b>baerbo...
# 17  [baerbock buch a, [[baerbock buch b<b>estselle...
# 18  [baerbock beine a, [[a<b>nnalena </b>baerbock ...
# 19  [baerbock bundeswehr a, [[a<b>nnalena </b>baer...
# 20  [baerbock bewertung a, [[baerbock a<b>ußenmini...
# 21  [baerbock corona a, [[baerbock corona a<b>ktue...
# 22  [baerbock corona aktuell a, [[baerbock corona ...
# 23  [baerbock corona wie geht es ihr a, [[baerbock...
# 24  [baerbock corona genesen a, [[baerbock corona ...
# 25  [baerbock china a, [[baerbock a<b>nd </b>china...
# 26  [baerbock cartoon a, [[baerbock a<b>ußenminist...
# 27  [baerbock corona wieder gesund a, [[baerbock c...
# 28  [baerbock cavusoglu a, [[baerbock cavusoglu al...
# 29  [baerbock cv a, [[baerbock a<b>nnalena </b>cv,...
# 30  [baerbock corona infektion a, [[baerbock coron...
#
#                                              suggests self_loops  \
# 0   [baerbock assange, baerbock außenministerin, b...         []
# 1   [baerbock assange auslieferung, annalena baerb...         []
# 2   [baerbock außenministerin alter, baerbock als ...         []
# 3   [annalena baerbock aachen, baerbock aachen bra...         []
# 4   [annalena baerbock abgenommen, baerbock abgeno...         []
# 5   [baerbock heute abend, baerbock heute ard, bae...         []
# 6   [baerbock als außenminister, annalena baerbock...         []
# 7   [annalena baerbock afrika, baerbock afrika bes...         []
# 8   [baerbock ausgeladen berlin, baerbock ausgelad...         []
# 9   [annalena baerbock auto, annalena baerbock aut...         []
# 10  [baerbock abschlussarbeit, annalena baerbock a...         []
# 11  [baerbock bali aktuell, baerbock bali aussprac...         []
# 12             [baerbock bei bild, bild baerbock cdu]         []
# 13  [baerbock beliebtheit aktuell, annalena baerbo...         []
# 14  [best of annalena baerbock, baerbock best of b...         []
# 15  [baerbock besuch ukraine aktuell, baerbock bes...         []
# 16  [annalena baerbock baltikum, baerbock baltikum...         []
# 17  [baerbock buch bestseller, baerbock biografie ...         []
# 18  [annalena baerbock beine, baerbock beine coron...         []
# 19  [annalena baerbock bundeswehr, baerbock bundes...         []
# 20  [baerbock außenministerin bewertung, annalena ...         []
# 21  [baerbock corona aktuell, annalena baerbock co...         []
# 22  [baerbock corona aktuell aachen, baerbock coro...         []
# 23  [baerbock corona wie geht es ihr an, baerbock ...         []
# 24  [baerbock corona genesen aktuell, baerbock cor...         []
# 25  [baerbock and china, anna baerbock china, baer...         []
# 26  [baerbock außenministerin cartoon, baerbock au...         []
# 27  [baerbock corona wieder gesund arbeiten, baerb...         []
# 28  [baerbock cavusoglu alter, baerbock cavusoglu ...         []
# 29  [baerbock annalena cv, baerbock lebenslauf ard...         []
# 30  [baerbock corona infektion aktuell, baerbock c...         []
#
#                                                  tags  depth      root  \
# 0   {'q': '_aID29LNBMkNdvT1HGcufNq-kFE', 't': {'bp...      0  baerbock
# 1   {'i': 'baerbock assange a', 'q': '2-Pdr-yU7hi8...      1  baerbock
# 2   {'i': 'baerbock außenministerin a', 'q': 'pGBQ...      1  baerbock
# 3   {'i': 'baerbock aachen a', 'q': '6F2buxiUTvVqA...      1  baerbock
# 4   {'i': 'baerbock abgenommen a', 'q': '2LGtFEE7x...      1  baerbock
# 5   {'i': 'baerbock aktuell a', 'q': 'OTFzBCaMS3qr...      1  baerbock
# 6   {'i': 'baerbock außenminister a', 'q': 'rDJMvh...      1  baerbock
# 7   {'i': 'baerbock afrika a', 'q': '97KMdaHBO064X...      1  baerbock
# 8   {'q': 'QUDd5j8fzLvxiDbEov_XFKmiJPQ', 't': {'bp...      1  baerbock
# 9   {'i': 'baerbock auto a', 'q': '85q6gOinQecr-Yc...      1  baerbock
# 10  {'i': 'baerbock abschluss a', 'o': 'baerbock <...      1  baerbock
# 11  {'i': 'baerbock bali a', 'q': 'eyC6KNtzuoDi4C_...      1  baerbock
# 12  {'q': '-gkWAtVqTv3VQ-grRqOO2nkFuug', 't': {'bp...      1  baerbock
# 13  {'i': 'baerbock beliebtheit a', 'q': 'fXCKjz8N...      1  baerbock
# 14  {'i': 'baerbock best of a', 'q': 'a-Ul_9XDtryd...      1  baerbock
# 15  {'i': 'baerbock besuch ukraine a', 'q': 'IqZz-...      1  baerbock
# 16  {'i': 'baerbock baltikum a', 'q': 'QGoolp2Clov...      1  baerbock
# 17  {'q': 'WsaoVBXnKp1gIc_Vxm-seRmGrBU', 't': {'bp...      1  baerbock
# 18  {'i': 'baerbock beine a', 'q': 'BIrvslF1By8K8K...      1  baerbock
# 19  {'i': 'baerbock bundeswehr a', 'q': 'Hdjqu40bX...      1  baerbock
# 20  {'i': 'baerbock bewertung a', 'q': 'qND4nrlPcD...      1  baerbock
# 21  {'i': 'baerbock corona a', 'q': '7QMwYXfLvd1of...      1  baerbock
# 22  {'i': 'baerbock corona aktuell a', 'q': 'GcLHP...      1  baerbock
# 23  {'i': 'baerbock corona wie geht es ihr a', 'q'...      1  baerbock
# 24  {'i': 'baerbock corona genesen a', 'q': '0EyoX...      1  baerbock
# 25  {'i': 'baerbock china a', 'q': '3nuUB1LcAcpwIH...      1  baerbock
# 26  {'i': 'baerbock cartoon a', 'q': 'D7mUuv0Tb75h...      1  baerbock
# 27  {'i': 'baerbock corona wieder gesund a', 'q': ...      1  baerbock
# 28  {'i': 'baerbock cavusoglu a', 'q': 'ImAgKMXBwJ...      1  baerbock
# 29  {'i': 'baerbock cv a', 'q': '03s4Q3anUG1OEDxeq...      1  baerbock
# 30  {'i': 'baerbock corona infektion a', 'q': 'Q9A...      1  baerbock
#
#    crawl_id
# 0      None
# 1      None
# 2      None
# 3      None
# 4      None
# 5      None
# 6      None
# 7      None
# 8      None
# 9      None
# 10     None
# 11     None
# 12     None
# 13     None
# 14     None
# 15     None
# 16     None
# 17     None
# 18     None
# 19     None
# 20     None
# 21     None
# 22     None
# 23     None
# 24     None
# 25     None
# 26     None
# 27     None
# 28     None
# 29     None
# 30     None

# %%
# export as csv
df = pd.DataFrame(tree)
df.to_csv('test_tree.csv', sep=';')

# %%
#df1 = pd.read_pickle(r'rai_app/export_file/export_test.pickle')
df_test = df1.head(10)
df_test
# Out:
#                 root                                               edge  \
# 0  christian eriksen     (christian eriksen, christian eriksen aktuell)
# 1  christian eriksen       (christian eriksen, christian eriksen alter)
# 2  christian eriksen        (christian eriksen, christian eriksen arzt)
# 3  christian eriksen  (christian eriksen, christian eriksen aktuelle...
# 4  christian eriksen       (christian eriksen, christian eriksen agent)
# 5  christian eriksen      (christian eriksen, christian eriksen attack)
# 6  christian eriksen  (christian eriksen, christian eriksen and simo...
# 7  christian eriksen   (christian eriksen, christian eriksen and covid)
# 8  christian eriksen  (christian eriksen, christian eriksen and harr...
# 9  christian eriksen  (christian eriksen, christian eriksen and family)
#
#               source                             target  rank  depth  \
# 0  christian eriksen          christian eriksen aktuell     1      0
# 1  christian eriksen            christian eriksen alter     2      0
# 2  christian eriksen             christian eriksen arzt     3      0
# 3  christian eriksen   christian eriksen aktuelle teams     4      0
# 4  christian eriksen            christian eriksen agent     5      0
# 5  christian eriksen           christian eriksen attack     6      0
# 6  christian eriksen  christian eriksen and simon kjaer     7      0
# 7  christian eriksen        christian eriksen and covid     8      0
# 8  christian eriksen   christian eriksen and harry kane     9      0
# 9  christian eriksen       christian eriksen and family    10      0
#
#   search_engine                    datetime grandparent parent  \
# 0        google  2022-07-08 14:15:59.326792        None   None
# 1        google  2022-07-08 14:15:59.326792        None   None
# 2        google  2022-07-08 14:15:59.326792        None   None
# 3        google  2022-07-08 14:15:59.326792        None   None
# 4        google  2022-07-08 14:15:59.326792        None   None
# 5        google  2022-07-08 14:15:59.326792        None   None
# 6        google  2022-07-08 14:15:59.326792        None   None
# 7        google  2022-07-08 14:15:59.326792        None   None
# 8        google  2022-07-08 14:15:59.326792        None   None
# 9        google  2022-07-08 14:15:59.326792        None   None
#
#           source_add       target_add
# 0  christian eriksen          aktuell
# 1  christian eriksen            alter
# 2  christian eriksen             arzt
# 3  christian eriksen   aktuelle teams
# 4  christian eriksen            agent
# 5  christian eriksen           attack
# 6  christian eriksen  and simon kjaer
# 7  christian eriksen        and covid
# 8  christian eriksen   and harry kane
# 9  christian eriksen       and family

# %% [markdown]
# ## trimming with levenshtein distance

# %%
b = ['baerbock annalena',
 'baerbock alter',
 'baerbock aktuell',
 'baerbock ausbildung',
 'baerbock annalena ehemann',
 'baerbock annalena privat',
 'baerbock afghanistan',
 'baerbock anne will',
 'baerbock buch',
 'baerbock bilder',
 'baerbock bikini',
 'baerbock bei putin',
 'baerbock beine',
 'baerbock blinken',
 'baerbock balkan',
 'baerbock beruf',
 'baerbock china',
 'baerbock cv',
 'baerbock corona bonus',
 'baerbock corona',
 'baerbock cartoon',
 'baerbock chancen',
 'baerbock comic',
 'baerbock corona hilfe',
 'baerbock droht russland',
 'baerbock dumme zitate',
 'baerbock dienstwagen',
 'baerbock droht',
 'baerbock droht putin',
 'baerbock doktorarbeit',
 'baerbock dissertation',
 'baerbock donbass',
 'baerbock englisch',
 'baerbock ehemann',
 'baerbock english',
 'baerbock eltern',
 'baerbock englisch video',
 'baerbock email',
 'baerbock englisch youtube',
 'baerbock eiffelturm',
 'baerbock familie',
 'baerbock facebook',
 'baerbock feet',
 'baerbock fotos',
 'baerbock fauxpas',
 'baerbock frisur',
 'baerbock pressefreiheit',
 'baerbock fehler',
 'baerbock gruene',
 'baerbock greenpeace',
 'baerbock gehalt',
 'baerbock g7',
 'baerbock germany',
 'baerbock gestern',
 'baerbock gewicht',
 'baerbock gegen putin',
 'baerbock habeck',
 'baerbock helm',
 'baerbock heute',
 'baerbock haustiere',
 'baerbock homepage',
 'baerbock hunde',
 'baerbock herkunft',
 'baerbock high heels',
 'baerbock israel',
 'baerbock in moskau',
 'baerbock in polen',
 'baerbock in russland',
 'baerbock in paris',
 'baerbock interview',
 'baerbock impfpflicht',
 'baerbock in israel',
 'baerbock jung',
 'baerbock jetzt',
 'baerbock junge dame',
 'baerbock jeans',
 'baerbock juristin',
 'baerbock jugendfoto',
 'baerbock jordanien',
 'baerbock junge welt',
 'baerbock kobold',
 'baerbock kinder',
 'baerbock kritik',
 'baerbock kosovo',
 'baerbock kontakt',
 'baerbock kleider',
 'baerbock kleidung',
 'baerbock kiew',
 'baerbock lebenslauf',
 'baerbock lawrow',
 'baerbock live',
 'baerbock lustig',
 'baerbock lindner',
 'baerbock laschet',
 'baerbock lanz',
 'baerbock laschet scholz',
 'baerbock mann',
 'baerbock moskau',
 'baerbock marokko',
 'baerbock merz',
 'baerbock morgan',
 'baerbock mode',
 'baerbock meme',
 'baerbock mantel moskau',
 'baerbock n wort',
 'baerbock nicht neutral',
 'baerbock nord stream 2',
 'baerbock n-wort',
 'baerbock n word',
 'baerbock n',
 'baerbock nato',
 'baerbock news heute',
 'baerbock ostkokaine',
 'baerbock oder habeck',
 'baerbock olympia',
 'baerbock outfit',
 'baerbock oderbruch',
 'baerbock oberweite',
 'baerbock oberstaufen',
 'baerbock ohrringe',
 'baerbock paris',
 'baerbock plagiat',
 'baerbock polen',
 'baerbock putin',
 'baerbock privat',
 'baerbock pressefreiheit',
 'baerbock peinlich',
 'baerbock pressekonferenz',
 'baerbock quellen',
 'baerbock iq',
 'baerbock eqs',
 'baerbock greenpeace',
 'baerbock gehalt',
 'baerbock annalena',
 'baerbock china',
 'baerbock gestern',
 'baerbock russland',
 'baerbock rede',
 'baerbock rede und',
 'baerbock rede englisch',
 'baerbock rede uno',
 'baerbock rede heute',
 'baerbock rede russland',
 'baerbock rede bundestag',
 'baerbock swift',
 'baerbock serbien',
 'baerbock studium',
 'baerbock skandale',
 'baerbock strache',
 'baerbock sprachfehler',
 'baerbock song',
 'baerbock spricht englisch',
 'baerbock twitter',
 'baerbock trampolin',
 'baerbock termine',
 'baerbock taz',
 'baerbock trampolinspringen',
 'baerbock tagesschau',
 'baerbock trampolin video',
 'baerbock triell',
 'baerbock un rede',
 'baerbock ukraine',
 'baerbock usa',
 'baerbock uno',
 'baerbock und',
 'baerbock und habeck',
 'baerbock ukraine-krise',
 'baerbock umfragewerte',
 'baerbock vita',
 'baerbock versprecher',
 'baerbock video',
 'baerbock versagt',
 'baerbock verspricht sich',
 'baerbock vor der uno',
 'baerbock vor un',
 'baerbock vereidigung',
 'baerbock wikipedia',
 'baerbock witwenrente',
 'baerbock witze',
 'baerbock warschau',
 'baerbock welt',
 'baerbock witwenrente abschaffen',
 'baerbock wohnort',
 'baerbock wahlkreis',
 'xbox',
 'xfinity',
 'xpo',
 'xrp',
 'x22',
 'xcel',
 'xom',
 'xmas',
 'baerbock youtube',
 'baerbock yad vashem',
 'baerbock young global leaders',
 'baerbock young leader',
 'annalena baerbock youtube',
 'baerbock wang yi',
 'annalena baerbock englisch youtube',
 'youtube baerbock englisch',
 'baerbock zitate',
 'baerbock zum russischen angriff',
 'baerbock zug',
 'baerbock zu ukraine',
 'baerbock zdf',
 'baerbock zur witwenrente',
 'baerbock zeit',
 'baerbock zustimmung']

# %%
len(b)
# Out:
# 208

# %%
list(map(lev_dist_list, b))
# Out:
# ['baerbock annalena',
#  'baerbock alter',
#  'baerbock aktuell',
#  'baerbock ausbildung',
#  'baerbock annalena ehemann',
#  'baerbock annalena privat',
#  'baerbock afghanistan',
#  'baerbock anne will',
#  'baerbock buch',
#  'baerbock bilder',
#  'baerbock bikini',
#  'baerbock bei putin',
#  'baerbock beine',
#  'baerbock blinken',
#  'baerbock balkan',
#  'baerbock beruf',
#  'baerbock china',
#  'baerbock cv',
#  'baerbock corona bonus',
#  'baerbock corona',
#  'baerbock cartoon',
#  'baerbock chancen',
#  'baerbock comic',
#  'baerbock corona hilfe',
#  'baerbock droht russland',
#  'baerbock dumme zitate',
#  'baerbock dienstwagen',
#  'baerbock droht',
#  'baerbock droht putin',
#  'baerbock doktorarbeit',
#  'baerbock dissertation',
#  'baerbock donbass',
#  'baerbock englisch',
#  'baerbock ehemann',
#  'baerbock english',
#  'baerbock eltern',
#  'baerbock englisch video',
#  'baerbock email',
#  'baerbock englisch youtube',
#  'baerbock eiffelturm',
#  'baerbock familie',
#  'baerbock facebook',
#  'baerbock feet',
#  'baerbock fotos',
#  'baerbock fauxpas',
#  'baerbock frisur',
#  'baerbock pressefreiheit',
#  'baerbock fehler',
#  'baerbock gruene',
#  'baerbock greenpeace',
#  'baerbock gehalt',
#  'baerbock g7',
#  'baerbock germany',
#  'baerbock gestern',
#  'baerbock gewicht',
#  'baerbock gegen putin',
#  'baerbock habeck',
#  'baerbock helm',
#  'baerbock heute',
#  'baerbock haustiere',
#  'baerbock homepage',
#  'baerbock hunde',
#  'baerbock herkunft',
#  'baerbock high heels',
#  'baerbock israel',
#  'baerbock in moskau',
#  'baerbock in polen',
#  'baerbock in russland',
#  'baerbock in paris',
#  'baerbock interview',
#  'baerbock impfpflicht',
#  'baerbock in israel',
#  'baerbock jung',
#  'baerbock jetzt',
#  'baerbock junge dame',
#  'baerbock jeans',
#  'baerbock juristin',
#  'baerbock jugendfoto',
#  'baerbock jordanien',
#  'baerbock junge welt',
#  'baerbock kobold',
#  'baerbock kinder',
#  'baerbock kritik',
#  'baerbock kosovo',
#  'baerbock kontakt',
#  'baerbock kleider',
#  'baerbock kleidung',
#  'baerbock kiew',
#  'baerbock lebenslauf',
#  'baerbock lawrow',
#  'baerbock live',
#  'baerbock lustig',
#  'baerbock lindner',
#  'baerbock laschet',
#  'baerbock lanz',
#  'baerbock laschet scholz',
#  'baerbock mann',
#  'baerbock moskau',
#  'baerbock marokko',
#  'baerbock merz',
#  'baerbock morgan',
#  'baerbock mode',
#  'baerbock meme',
#  'baerbock mantel moskau',
#  'baerbock n wort',
#  'baerbock nicht neutral',
#  'baerbock nord stream 2',
#  'baerbock n-wort',
#  'baerbock n word',
#  'baerbock n',
#  'baerbock nato',
#  'baerbock news heute',
#  'baerbock ostkokaine',
#  'baerbock oder habeck',
#  'baerbock olympia',
#  'baerbock outfit',
#  'baerbock oderbruch',
#  'baerbock oberweite',
#  'baerbock oberstaufen',
#  'baerbock ohrringe',
#  'baerbock paris',
#  'baerbock plagiat',
#  'baerbock polen',
#  'baerbock putin',
#  'baerbock privat',
#  'baerbock pressefreiheit',
#  'baerbock peinlich',
#  'baerbock pressekonferenz',
#  'baerbock quellen',
#  'baerbock iq',
#  'baerbock eqs',
#  'baerbock greenpeace',
#  'baerbock gehalt',
#  'baerbock annalena',
#  'baerbock china',
#  'baerbock gestern',
#  'baerbock russland',
#  'baerbock rede',
#  'baerbock rede und',
#  'baerbock rede englisch',
#  'baerbock rede uno',
#  'baerbock rede heute',
#  'baerbock rede russland',
#  'baerbock rede bundestag',
#  'baerbock swift',
#  'baerbock serbien',
#  'baerbock studium',
#  'baerbock skandale',
#  'baerbock strache',
#  'baerbock sprachfehler',
#  'baerbock song',
#  'baerbock spricht englisch',
#  'baerbock twitter',
#  'baerbock trampolin',
#  'baerbock termine',
#  'baerbock taz',
#  'baerbock trampolinspringen',
#  'baerbock tagesschau',
#  'baerbock trampolin video',
#  'baerbock triell',
#  'baerbock un rede',
#  'baerbock ukraine',
#  'baerbock usa',
#  'baerbock uno',
#  'baerbock und',
#  'baerbock und habeck',
#  'baerbock ukraine-krise',
#  'baerbock umfragewerte',
#  'baerbock vita',
#  'baerbock versprecher',
#  'baerbock video',
#  'baerbock versagt',
#  'baerbock verspricht sich',
#  'baerbock vor der uno',
#  'baerbock vor un',
#  'baerbock vereidigung',
#  'baerbock wikipedia',
#  'baerbock witwenrente',
#  'baerbock witze',
#  'baerbock warschau',
#  'baerbock welt',
#  'baerbock witwenrente abschaffen',
#  'baerbock wohnort',
#  'baerbock wahlkreis',
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  'baerbock youtube',
#  'baerbock yad vashem',
#  'baerbock young global leaders',
#  'baerbock young leader',
#  'annalena baerbock youtube',
#  'baerbock wang yi',
#  'annalena baerbock englisch youtube',
#  'youtube baerbock englisch',
#  'baerbock zitate',
#  'baerbock zum russischen angriff',
#  'baerbock zug',
#  'baerbock zu ukraine',
#  'baerbock zdf',
#  'baerbock zur witwenrente',
#  'baerbock zeit',
#  'baerbock zustimmung']

# %%
b
# Out:
# ['baerbock annalena',
#  'baerbock alter',
#  'baerbock aktuell',
#  'baerbock ausbildung',
#  'baerbock annalena ehemann',
#  'baerbock annalena privat',
#  'baerbock afghanistan',
#  'baerbock anne will',
#  'baerbock buch',
#  'baerbock bilder',
#  'baerbock bikini',
#  'baerbock bei putin',
#  'baerbock beine',
#  'baerbock blinken',
#  'baerbock balkan',
#  'baerbock beruf',
#  'baerbock china',
#  'baerbock cv',
#  'baerbock corona bonus',
#  'baerbock corona',
#  'baerbock cartoon',
#  'baerbock chancen',
#  'baerbock comic',
#  'baerbock corona hilfe',
#  'baerbock droht russland',
#  'baerbock dumme zitate',
#  'baerbock dienstwagen',
#  'baerbock droht',
#  'baerbock droht putin',
#  'baerbock doktorarbeit',
#  'baerbock dissertation',
#  'baerbock donbass',
#  'baerbock englisch',
#  'baerbock ehemann',
#  'baerbock english',
#  'baerbock eltern',
#  'baerbock englisch video',
#  'baerbock email',
#  'baerbock englisch youtube',
#  'baerbock eiffelturm',
#  'baerbock familie',
#  'baerbock facebook',
#  'baerbock feet',
#  'baerbock fotos',
#  'baerbock fauxpas',
#  'baerbock frisur',
#  'baerbock pressefreiheit',
#  'baerbock fehler',
#  'baerbock gruene',
#  'baerbock greenpeace',
#  'baerbock gehalt',
#  'baerbock g7',
#  'baerbock germany',
#  'baerbock gestern',
#  'baerbock gewicht',
#  'baerbock gegen putin',
#  'baerbock habeck',
#  'baerbock helm',
#  'baerbock heute',
#  'baerbock haustiere',
#  'baerbock homepage',
#  'baerbock hunde',
#  'baerbock herkunft',
#  'baerbock high heels',
#  'baerbock israel',
#  'baerbock in moskau',
#  'baerbock in polen',
#  'baerbock in russland',
#  'baerbock in paris',
#  'baerbock interview',
#  'baerbock impfpflicht',
#  'baerbock in israel',
#  'baerbock jung',
#  'baerbock jetzt',
#  'baerbock junge dame',
#  'baerbock jeans',
#  'baerbock juristin',
#  'baerbock jugendfoto',
#  'baerbock jordanien',
#  'baerbock junge welt',
#  'baerbock kobold',
#  'baerbock kinder',
#  'baerbock kritik',
#  'baerbock kosovo',
#  'baerbock kontakt',
#  'baerbock kleider',
#  'baerbock kleidung',
#  'baerbock kiew',
#  'baerbock lebenslauf',
#  'baerbock lawrow',
#  'baerbock live',
#  'baerbock lustig',
#  'baerbock lindner',
#  'baerbock laschet',
#  'baerbock lanz',
#  'baerbock laschet scholz',
#  'baerbock mann',
#  'baerbock moskau',
#  'baerbock marokko',
#  'baerbock merz',
#  'baerbock morgan',
#  'baerbock mode',
#  'baerbock meme',
#  'baerbock mantel moskau',
#  'baerbock n wort',
#  'baerbock nicht neutral',
#  'baerbock nord stream 2',
#  'baerbock n-wort',
#  'baerbock n word',
#  'baerbock n',
#  'baerbock nato',
#  'baerbock news heute',
#  'baerbock ostkokaine',
#  'baerbock oder habeck',
#  'baerbock olympia',
#  'baerbock outfit',
#  'baerbock oderbruch',
#  'baerbock oberweite',
#  'baerbock oberstaufen',
#  'baerbock ohrringe',
#  'baerbock paris',
#  'baerbock plagiat',
#  'baerbock polen',
#  'baerbock putin',
#  'baerbock privat',
#  'baerbock pressefreiheit',
#  'baerbock peinlich',
#  'baerbock pressekonferenz',
#  'baerbock quellen',
#  'baerbock iq',
#  'baerbock eqs',
#  'baerbock greenpeace',
#  'baerbock gehalt',
#  'baerbock annalena',
#  'baerbock china',
#  'baerbock gestern',
#  'baerbock russland',
#  'baerbock rede',
#  'baerbock rede und',
#  'baerbock rede englisch',
#  'baerbock rede uno',
#  'baerbock rede heute',
#  'baerbock rede russland',
#  'baerbock rede bundestag',
#  'baerbock swift',
#  'baerbock serbien',
#  'baerbock studium',
#  'baerbock skandale',
#  'baerbock strache',
#  'baerbock sprachfehler',
#  'baerbock song',
#  'baerbock spricht englisch',
#  'baerbock twitter',
#  'baerbock trampolin',
#  'baerbock termine',
#  'baerbock taz',
#  'baerbock trampolinspringen',
#  'baerbock tagesschau',
#  'baerbock trampolin video',
#  'baerbock triell',
#  'baerbock un rede',
#  'baerbock ukraine',
#  'baerbock usa',
#  'baerbock uno',
#  'baerbock und',
#  'baerbock und habeck',
#  'baerbock ukraine-krise',
#  'baerbock umfragewerte',
#  'baerbock vita',
#  'baerbock versprecher',
#  'baerbock video',
#  'baerbock versagt',
#  'baerbock verspricht sich',
#  'baerbock vor der uno',
#  'baerbock vor un',
#  'baerbock vereidigung',
#  'baerbock wikipedia',
#  'baerbock witwenrente',
#  'baerbock witze',
#  'baerbock warschau',
#  'baerbock welt',
#  'baerbock witwenrente abschaffen',
#  'baerbock wohnort',
#  'baerbock wahlkreis',
#  'xbox',
#  'xfinity',
#  'xpo',
#  'xrp',
#  'x22',
#  'xcel',
#  'xom',
#  'xmas',
#  'baerbock youtube',
#  'baerbock yad vashem',
#  'baerbock young global leaders',
#  'baerbock young leader',
#  'annalena baerbock youtube',
#  'baerbock wang yi',
#  'annalena baerbock englisch youtube',
#  'youtube baerbock englisch',
#  'baerbock zitate',
#  'baerbock zum russischen angriff',
#  'baerbock zug',
#  'baerbock zu ukraine',
#  'baerbock zdf',
#  'baerbock zur witwenrente',
#  'baerbock zeit',
#  'baerbock zustimmung']

# %% [markdown]
# # main testing

# %%
def load_data(file):
    df = pd.read_excel(file)
    df['querrys'] = df['Vorname'] + ' ' + df['Name'] # create querry term column 
    return df

# %%
def get_user_input():
    input_source = input('Which search engine? Available selection: "google" or "bing"\n Input: ')
    input_max_depth = int(input('To what maximum depth should the search be carried out? Note: It is recommended to start with 1 \n Input: '))
    user_input = {'source': input_source,
             'max_depth': input_max_depth}
    return user_input

# %%
def main():
    import_path = 'rai_app/import_file/import.xlsx'
    export_path = 'rai_app/export_file/'

    file = load_data(import_path)
    df = pd.DataFrame()

    user_input = get_user_input()
    # Crawl querrys and safe output 
    for querry in file['querrys']:
        # Generating a suggestions tree
        tree = suggests.get_suggests_tree(querry.lower(), source=user_input['source'], max_depth=user_input['max_depth'])
        
        # Reduce to new information obtained in suggestions
        edges = suggests.to_edgelist(tree)
        edges = suggests.add_parent_nodes(edges)
        try:
            edges = edges.apply(suggests.add_metanodes, axis=1)
            # Append output to df
            df = pd.concat([df,edges])
        except AttributeError:
            pass
    
    df['target'] = df.apply(lev_dist_row, axis=1)
    df = df.loc[df.target!='delete']
    
    return df

# %%
df = main()
# Out:
# 2022-07-08 17:50:38,026 | 2156 | INFO | rai_app.suggests.logger | google | christian eriksen
# 2022-07-08 17:50:38,550 | 2156 | INFO | rai_app.suggests.logger | google | christian eriksen
# 2022-07-08 17:50:39,114 | 2156 | INFO | rai_app.suggests.logger | google | christian eriksen
# 2022-07-08 17:50:39,512 | 2156 | INFO | rai_app.suggests.logger | google | alec baldwin
# 2022-07-08 17:50:40,304 | 2156 | INFO | rai_app.suggests.logger | google | alec baldwin
# 2022-07-08 17:50:40,871 | 2156 | INFO | rai_app.suggests.logger | google | alec baldwin
# 2022-07-08 17:50:41,466 | 2156 | INFO | rai_app.suggests.logger | google | gil ofarim
# 2022-07-08 17:50:42,234 | 2156 | INFO | rai_app.suggests.logger | google | gil ofarim
# 2022-07-08 17:50:42,724 | 2156 | INFO | rai_app.suggests.logger | google | gil ofarim
# 2022-07-08 17:50:43,370 | 2156 | INFO | rai_app.suggests.logger | google | armin laschet
# 2022-07-08 17:50:44,011 | 2156 | INFO | rai_app.suggests.logger | google | armin laschet
# 2022-07-08 17:50:44,603 | 2156 | INFO | rai_app.suggests.logger | google | armin laschet
# 2022-07-08 17:50:45,031 | 2156 | INFO | rai_app.suggests.logger | google | olaf scholz
# 2022-07-08 17:50:45,628 | 2156 | INFO | rai_app.suggests.logger | google | olaf scholz
# 2022-07-08 17:50:46,072 | 2156 | INFO | rai_app.suggests.logger | google | olaf scholz
# 2022-07-08 17:50:46,562 | 2156 | INFO | rai_app.suggests.logger | google | annalena baerbock
# 2022-07-08 17:50:47,283 | 2156 | INFO | rai_app.suggests.logger | google | annalena baerbock
# 2022-07-08 17:50:47,988 | 2156 | INFO | rai_app.suggests.logger | google | annalena baerbock
# 2022-07-08 17:50:48,522 | 2156 | INFO | rai_app.suggests.logger | google | mike singer
# 2022-07-08 17:50:49,134 | 2156 | INFO | rai_app.suggests.logger | google | mike singer
# 2022-07-08 17:50:49,805 | 2156 | INFO | rai_app.suggests.logger | google | mike singer
# 2022-07-08 17:50:50,491 | 2156 | INFO | rai_app.suggests.logger | google | michael ballack
# 2022-07-08 17:50:51,216 | 2156 | INFO | rai_app.suggests.logger | google | michael ballack
# 2022-07-08 17:50:51,717 | 2156 | INFO | rai_app.suggests.logger | google | michael ballack
# 2022-07-08 17:50:52,252 | 2156 | INFO | rai_app.suggests.logger | google | thomas gottschalk
# 2022-07-08 17:50:52,941 | 2156 | INFO | rai_app.suggests.logger | google | thomas gottschalk
# 2022-07-08 17:50:53,700 | 2156 | INFO | rai_app.suggests.logger | google | thomas gottschalk
# 2022-07-08 17:50:54,372 | 2156 | INFO | rai_app.suggests.logger | google | jerome boateng
# 2022-07-08 17:50:55,090 | 2156 | INFO | rai_app.suggests.logger | google | jerome boateng
# 2022-07-08 17:50:55,562 | 2156 | INFO | rai_app.suggests.logger | google | jerome boateng
# 2022-07-08 17:50:56,083 | 2156 | INFO | rai_app.suggests.logger | google | joe biden
# 2022-07-08 17:50:56,755 | 2156 | INFO | rai_app.suggests.logger | google | joe biden
# 2022-07-08 17:50:57,276 | 2156 | INFO | rai_app.suggests.logger | google | joe biden
# 2022-07-08 17:50:57,734 | 2156 | INFO | rai_app.suggests.logger | google | boris johnson
# 2022-07-08 17:50:58,375 | 2156 | INFO | rai_app.suggests.logger | google | boris johnson
# 2022-07-08 17:50:59,078 | 2156 | INFO | rai_app.suggests.logger | google | boris johnson
# 2022-07-08 17:50:59,489 | 2156 | INFO | rai_app.suggests.logger | google | jong-un kim
# 2022-07-08 17:51:00,191 | 2156 | INFO | rai_app.suggests.logger | google | jong-un kim
# 2022-07-08 17:51:00,803 | 2156 | INFO | rai_app.suggests.logger | google | jong-un kim
# 2022-07-08 17:51:01,323 | 2156 | INFO | rai_app.suggests.logger | google | laura müller
# 2022-07-08 17:51:01,872 | 2156 | INFO | rai_app.suggests.logger | google | laura müller
# 2022-07-08 17:51:02,405 | 2156 | INFO | rai_app.suggests.logger | google | laura müller
# 2022-07-08 17:51:03,202 | 2156 | INFO | rai_app.suggests.logger | google | michael wendler
# 2022-07-08 17:51:04,031 | 2156 | INFO | rai_app.suggests.logger | google | michael wendler
# 2022-07-08 17:51:04,722 | 2156 | INFO | rai_app.suggests.logger | google | michael wendler
# 2022-07-08 17:51:05,239 | 2156 | INFO | rai_app.suggests.logger | google | kamala harris
# 2022-07-08 17:51:06,075 | 2156 | INFO | rai_app.suggests.logger | google | kamala harris
# 2022-07-08 17:51:06,627 | 2156 | INFO | rai_app.suggests.logger | google | kamala harris
# 2022-07-08 17:51:07,346 | 2156 | INFO | rai_app.suggests.logger | google | attila hildmann
# 2022-07-08 17:51:08,217 | 2156 | INFO | rai_app.suggests.logger | google | attila hildmann
# 2022-07-08 17:51:08,929 | 2156 | INFO | rai_app.suggests.logger | google | attila hildmann
# 2022-07-08 17:51:09,553 | 2156 | INFO | rai_app.suggests.logger | google | claudia obert
# 2022-07-08 17:51:10,364 | 2156 | INFO | rai_app.suggests.logger | google | claudia obert
# 2022-07-08 17:51:10,757 | 2156 | INFO | rai_app.suggests.logger | google | claudia obert
# 2022-07-08 17:51:11,454 | 2156 | INFO | rai_app.suggests.logger | google | sonja kirchberger
# 2022-07-08 17:51:12,219 | 2156 | INFO | rai_app.suggests.logger | google | sonja kirchberger
# 2022-07-08 17:51:12,964 | 2156 | INFO | rai_app.suggests.logger | google | sonja kirchberger
# 2022-07-08 17:51:13,446 | 2156 | INFO | rai_app.suggests.logger | google | melania trump
# 2022-07-08 17:51:13,961 | 2156 | INFO | rai_app.suggests.logger | google | melania trump
# 2022-07-08 17:51:14,536 | 2156 | INFO | rai_app.suggests.logger | google | melania trump
# 2022-07-08 17:51:15,126 | 2156 | INFO | rai_app.suggests.logger | google | greta thunberg
# 2022-07-08 17:51:15,759 | 2156 | INFO | rai_app.suggests.logger | google | greta thunberg
# 2022-07-08 17:51:16,183 | 2156 | INFO | rai_app.suggests.logger | google | greta thunberg
# 2022-07-08 17:51:16,851 | 2156 | INFO | rai_app.suggests.logger | google | evelyn burdecki
# 2022-07-08 17:51:17,470 | 2156 | INFO | rai_app.suggests.logger | google | evelyn burdecki
# 2022-07-08 17:51:17,925 | 2156 | INFO | rai_app.suggests.logger | google | evelyn burdecki
# 2022-07-08 17:51:18,428 | 2156 | INFO | rai_app.suggests.logger | google | alice merton
# 2022-07-08 17:51:19,163 | 2156 | INFO | rai_app.suggests.logger | google | alice merton
# 2022-07-08 17:51:19,572 | 2156 | INFO | rai_app.suggests.logger | google | alice merton
# 2022-07-08 17:51:20,250 | 2156 | INFO | rai_app.suggests.logger | google | peter ortloff
# 2022-07-08 17:51:20,950 | 2156 | INFO | rai_app.suggests.logger | google | peter ortloff
# 2022-07-08 17:51:21,705 | 2156 | INFO | rai_app.suggests.logger | google | peter ortloff
# 2022-07-08 17:51:22,314 | 2156 | INFO | rai_app.suggests.logger | google | bastian yottta
# 2022-07-08 17:51:23,101 | 2156 | INFO | rai_app.suggests.logger | google | bastian yottta
# 2022-07-08 17:51:23,511 | 2156 | INFO | rai_app.suggests.logger | google | bastian yottta
# 2022-07-08 17:51:24,194 | 2156 | INFO | rai_app.suggests.logger | google | luke mockridge
# 2022-07-08 17:51:24,814 | 2156 | INFO | rai_app.suggests.logger | google | luke mockridge
# 2022-07-08 17:51:25,468 | 2156 | INFO | rai_app.suggests.logger | google | luke mockridge
# 2022-07-08 17:51:26,043 | 2156 | INFO | rai_app.suggests.logger | google | leila lowfire
# 2022-07-08 17:51:26,509 | 2156 | INFO | rai_app.suggests.logger | google | leila lowfire
# 2022-07-08 17:51:27,215 | 2156 | INFO | rai_app.suggests.logger | google | leila lowfire
# 2022-07-08 17:51:27,951 | 2156 | INFO | rai_app.suggests.logger | google | chris töpperwien
# 2022-07-08 17:51:28,720 | 2156 | INFO | rai_app.suggests.logger | google | chris töpperwien
# 2022-07-08 17:51:29,415 | 2156 | INFO | rai_app.suggests.logger | google | chris töpperwien
# 2022-07-08 17:51:30,103 | 2156 | INFO | rai_app.suggests.logger | google | saskia esken
# 2022-07-08 17:51:30,830 | 2156 | INFO | rai_app.suggests.logger | google | saskia esken
# 2022-07-08 17:51:31,456 | 2156 | INFO | rai_app.suggests.logger | google | saskia esken
# 2022-07-08 17:51:32,230 | 2156 | INFO | rai_app.suggests.logger | google | doreen dietel
# 2022-07-08 17:51:33,056 | 2156 | INFO | rai_app.suggests.logger | google | doreen dietel
# 2022-07-08 17:51:33,649 | 2156 | INFO | rai_app.suggests.logger | google | doreen dietel
# 2022-07-08 17:51:34,073 | 2156 | INFO | rai_app.suggests.logger | google | daniel küblböck
# 2022-07-08 17:51:34,603 | 2156 | INFO | rai_app.suggests.logger | google | daniel küblböck
# 2022-07-08 17:51:35,224 | 2156 | INFO | rai_app.suggests.logger | google | daniel küblböck
# 2022-07-08 17:51:35,830 | 2156 | INFO | rai_app.suggests.logger | google | meghan markle
# 2022-07-08 17:51:36,277 | 2156 | INFO | rai_app.suggests.logger | google | meghan markle
# 2022-07-08 17:51:36,638 | 2156 | INFO | rai_app.suggests.logger | google | meghan markle
# 2022-07-08 17:51:37,088 | 2156 | INFO | rai_app.suggests.logger | google | jan ullrich
# 2022-07-08 17:51:37,721 | 2156 | INFO | rai_app.suggests.logger | google | jan ullrich
# 2022-07-08 17:51:38,268 | 2156 | INFO | rai_app.suggests.logger | google | jan ullrich
# 2022-07-08 17:51:38,869 | 2156 | INFO | rai_app.suggests.logger | google | hans-georg maaßen
# 2022-07-08 17:51:39,341 | 2156 | INFO | rai_app.suggests.logger | google | hans-georg maaßen
# 2022-07-08 17:51:40,025 | 2156 | INFO | rai_app.suggests.logger | google | hans-georg maaßen
# 2022-07-08 17:51:40,722 | 2156 | INFO | rai_app.suggests.logger | google | demi lovato
# 2022-07-08 17:51:41,472 | 2156 | INFO | rai_app.suggests.logger | google | demi lovato
# 2022-07-08 17:51:42,124 | 2156 | INFO | rai_app.suggests.logger | google | demi lovato
# 2022-07-08 17:51:42,575 | 2156 | INFO | rai_app.suggests.logger | google | mesut özil
# 2022-07-08 17:51:43,175 | 2156 | INFO | rai_app.suggests.logger | google | mesut özil
# 2022-07-08 17:51:43,763 | 2156 | INFO | rai_app.suggests.logger | google | mesut özil
# 2022-07-08 17:51:44,548 | 2156 | INFO | rai_app.suggests.logger | google | horst seehofer
# 2022-07-08 17:51:45,015 | 2156 | INFO | rai_app.suggests.logger | google | horst seehofer
# 2022-07-08 17:51:45,547 | 2156 | INFO | rai_app.suggests.logger | google | horst seehofer
# 2022-07-08 17:51:46,094 | 2156 | INFO | rai_app.suggests.logger | google | tina york
# 2022-07-08 17:51:46,595 | 2156 | INFO | rai_app.suggests.logger | google | tina york
# 2022-07-08 17:51:47,336 | 2156 | INFO | rai_app.suggests.logger | google | tina york
# 2022-07-08 17:51:48,067 | 2156 | INFO | rai_app.suggests.logger | google | sylvester stallone
# 2022-07-08 17:51:48,627 | 2156 | INFO | rai_app.suggests.logger | google | sylvester stallone
# 2022-07-08 17:51:49,398 | 2156 | INFO | rai_app.suggests.logger | google | sylvester stallone
# 2022-07-08 17:51:50,063 | 2156 | INFO | rai_app.suggests.logger | google | ella endlich
# 2022-07-08 17:51:50,852 | 2156 | INFO | rai_app.suggests.logger | google | ella endlich
# 2022-07-08 17:51:51,214 | 2156 | INFO | rai_app.suggests.logger | google | ella endlich
# 2022-07-08 17:51:51,773 | 2156 | INFO | rai_app.suggests.logger | google | donald trump
# 2022-07-08 17:51:52,347 | 2156 | INFO | rai_app.suggests.logger | google | donald trump
# 2022-07-08 17:51:52,819 | 2156 | INFO | rai_app.suggests.logger | google | donald trump
# 2022-07-08 17:51:53,377 | 2156 | INFO | rai_app.suggests.logger | google | shirin david
# 2022-07-08 17:51:54,148 | 2156 | INFO | rai_app.suggests.logger | google | shirin david
# 2022-07-08 17:51:54,771 | 2156 | INFO | rai_app.suggests.logger | google | shirin david
# 2022-07-08 17:51:55,210 | 2156 | INFO | rai_app.suggests.logger | google | kader loth
# 2022-07-08 17:51:55,723 | 2156 | INFO | rai_app.suggests.logger | google | kader loth
# 2022-07-08 17:51:56,160 | 2156 | INFO | rai_app.suggests.logger | google | kader loth
# 2022-07-08 17:51:56,840 | 2156 | INFO | rai_app.suggests.logger | google | lena meyer-landrut
# 2022-07-08 17:51:57,354 | 2156 | INFO | rai_app.suggests.logger | google | lena meyer-landrut
# 2022-07-08 17:51:57,854 | 2156 | INFO | rai_app.suggests.logger | google | lena meyer-landrut
# 2022-07-08 17:51:58,444 | 2156 | INFO | rai_app.suggests.logger | google | mireille mathieu
# 2022-07-08 17:51:59,033 | 2156 | INFO | rai_app.suggests.logger | google | mireille mathieu
# 2022-07-08 17:51:59,743 | 2156 | INFO | rai_app.suggests.logger | google | mireille mathieu
# 2022-07-08 17:52:00,454 | 2156 | INFO | rai_app.suggests.logger | google | ousmane dembele
# 2022-07-08 17:52:00,926 | 2156 | INFO | rai_app.suggests.logger | google | ousmane dembele
# 2022-07-08 17:52:01,592 | 2156 | INFO | rai_app.suggests.logger | google | ousmane dembele
# 2022-07-08 17:52:02,258 | 2156 | INFO | rai_app.suggests.logger | google | peter kraus
# 2022-07-08 17:52:02,912 | 2156 | INFO | rai_app.suggests.logger | google | peter kraus
# 2022-07-08 17:52:03,397 | 2156 | INFO | rai_app.suggests.logger | google | peter kraus
# 2022-07-08 17:52:04,144 | 2156 | INFO | rai_app.suggests.logger | google | alice weidel
# 2022-07-08 17:52:04,887 | 2156 | INFO | rai_app.suggests.logger | google | alice weidel
# 2022-07-08 17:52:05,588 | 2156 | INFO | rai_app.suggests.logger | google | alice weidel
# 2022-07-08 17:52:06,330 | 2156 | INFO | rai_app.suggests.logger | google | meghan markle
# 2022-07-08 17:52:06,725 | 2156 | INFO | rai_app.suggests.logger | google | meghan markle
# 2022-07-08 17:52:07,410 | 2156 | INFO | rai_app.suggests.logger | google | meghan markle
# 2022-07-08 17:52:07,972 | 2156 | INFO | rai_app.suggests.logger | google | florian weiss
# 2022-07-08 17:52:08,762 | 2156 | INFO | rai_app.suggests.logger | google | florian weiss
# 2022-07-08 17:52:09,173 | 2156 | INFO | rai_app.suggests.logger | google | florian weiss

# %%
df
# Out:
#                  root                                               edge  \
# 0   christian eriksen     (christian eriksen, christian eriksen aktuell)
# 1   christian eriksen       (christian eriksen, christian eriksen alter)
# 2   christian eriksen        (christian eriksen, christian eriksen arzt)
# 3   christian eriksen  (christian eriksen, christian eriksen aktuelle...
# 4   christian eriksen       (christian eriksen, christian eriksen agent)
# ..                ...                                                ...
# 15      florian weiss                (florian weiss, florian wess botox)
# 16      florian weiss              (florian weiss, florian weiss bridge)
# 17      florian weiss        (florian weiss, florian weiss besserwisser)
# 18      florian weiss         (florian weiss, florian weiss betonbohren)
# 19      florian weiss           (florian weiss, florian weiss badbergen)
#
#                source                            target  rank  depth  \
# 0   christian eriksen         christian eriksen aktuell     1      0
# 1   christian eriksen           christian eriksen alter     2      0
# 2   christian eriksen            christian eriksen arzt     3      0
# 3   christian eriksen  christian eriksen aktuelle teams     4      0
# 4   christian eriksen           christian eriksen agent     5      0
# ..                ...                               ...   ...    ...
# 15      florian weiss                florian wess botox    16      0
# 16      florian weiss              florian weiss bridge    17      0
# 17      florian weiss        florian weiss besserwisser    18      0
# 18      florian weiss         florian weiss betonbohren    19      0
# 19      florian weiss           florian weiss badbergen    20      0
#
#    search_engine                    datetime grandparent parent  \
# 0         google  2022-07-08 15:50:37.480972        None   None
# 1         google  2022-07-08 15:50:37.480972        None   None
# 2         google  2022-07-08 15:50:37.480972        None   None
# 3         google  2022-07-08 15:50:37.480972        None   None
# 4         google  2022-07-08 15:50:37.480972        None   None
# ..           ...                         ...         ...    ...
# 15        google  2022-07-08 15:52:07.490813        None   None
# 16        google  2022-07-08 15:52:07.490813        None   None
# 17        google  2022-07-08 15:52:07.490813        None   None
# 18        google  2022-07-08 15:52:07.490813        None   None
# 19        google  2022-07-08 15:52:07.490813        None   None
#
#            source_add      target_add
# 0   christian eriksen         aktuell
# 1   christian eriksen           alter
# 2   christian eriksen            arzt
# 3   christian eriksen  aktuelle teams
# 4   christian eriksen           agent
# ..                ...             ...
# 15      florian weiss      wess botox
# 16      florian weiss          bridge
# 17      florian weiss    besserwisser
# 18      florian weiss     betonbohren
# 19      florian weiss       badbergen
#
# [1289 rows x 12 columns]

# %%
#df1['target'] = df1.apply(lev_dist_row, axis=1)
df1.loc[df1.target!='delete']
# Out:
#                   root                                               edge  \
# 0    christian eriksen     (christian eriksen, christian eriksen aktuell)
# 1    christian eriksen       (christian eriksen, christian eriksen alter)
# 2    christian eriksen        (christian eriksen, christian eriksen arzt)
# 3    christian eriksen  (christian eriksen, christian eriksen aktuelle...
# 4    christian eriksen       (christian eriksen, christian eriksen agent)
# ..                 ...                                                ...
# 402      florian weiss  (florian weiss badbergen, florian weiss badber...
# 403      florian weiss  (florian weiss badbergen, florian weiss badber...
# 404      florian weiss  (florian weiss badbergen, florian weiss badber...
# 405      florian weiss  (florian weiss badbergen, florian weiss badber...
# 406      florian weiss  (florian weiss badbergen, florian weiss badber...
#
#                       source                                 target  rank  \
# 0          christian eriksen              christian eriksen aktuell     1
# 1          christian eriksen                christian eriksen alter     2
# 2          christian eriksen                 christian eriksen arzt     3
# 3          christian eriksen       christian eriksen aktuelle teams     4
# 4          christian eriksen                christian eriksen agent     5
# ..                       ...                                    ...   ...
# 402  florian weiss badbergen         florian weiss badbergen corona     9
# 403  florian weiss badbergen       florian weiss badbergen coaching    10
# 404  florian weiss badbergen           florian weiss badbergen chef    11
# 405  florian weiss badbergen  florian weiss badbergen corona regeln    12
# 406  florian weiss badbergen    florian weiss badbergen corona test    13
#
#      depth search_engine                    datetime grandparent  \
# 0        0        google  2022-07-08 14:15:59.326792        None
# 1        0        google  2022-07-08 14:15:59.326792        None
# 2        0        google  2022-07-08 14:15:59.326792        None
# 3        0        google  2022-07-08 14:15:59.326792        None
# 4        0        google  2022-07-08 14:15:59.326792        None
# ..     ...           ...                         ...         ...
# 402      1        google  2022-07-08 14:55:25.201143        None
# 403      1        google  2022-07-08 14:55:25.201143        None
# 404      1        google  2022-07-08 14:55:25.201143        None
# 405      1        google  2022-07-08 14:55:25.201143        None
# 406      1        google  2022-07-08 14:55:25.201143        None
#
#             parent         source_add      target_add
# 0             None  christian eriksen         aktuell
# 1             None  christian eriksen           alter
# 2             None  christian eriksen            arzt
# 3             None  christian eriksen  aktuelle teams
# 4             None  christian eriksen           agent
# ..             ...                ...             ...
# 402  florian weiss          badbergen          corona
# 403  florian weiss          badbergen        coaching
# 404  florian weiss          badbergen            chef
# 405  florian weiss          badbergen   corona regeln
# 406  florian weiss          badbergen     corona test
#
# [24045 rows x 12 columns]

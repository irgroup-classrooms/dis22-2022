# %%
import suggests
import string

# %%
g = suggests.get_suggests('baerbock', source='google')
# Out:
# 2022-04-28 16:14:55,481 | 15768 | INFO | logger | google | baerbock
# 2022-04-28 16:14:56,917 | 15768 | INFO | logger | google | baerbock
# 2022-04-28 16:14:58,084 | 15768 | INFO | logger | google | baerbock

# %%
g['suggests']
# Out:
# ['baerbock außenministerin',
#  'baerbock abgenommen',
#  'baerbock assange',
#  'baerbock amt',
#  'baerbock auto',
#  'baerbock außenpolitik',
#  'baerbock ard',
#  'baerbock an der front',
#  'baerbock ansprache',
#  'baerbock afghanistan',
#  'baerbock beliebtheit',
#  'baerbock buch',
#  'baerbock bademantel',
#  'baerbock bilder',
#  'baerbock bei putin',
#  'baerbock besuch ukraine',
#  'baerbock biografie',
#  'baerbock besuch russland',
#  'baerbock bild',
#  'baerbock beliebt',
#  'baerbock china',
#  'baerbock cv',
#  'baerbock cnn',
#  'baerbock cairo',
#  'baerbock cartoon',
#  'baerbock chemnitz',
#  'baerbock clinton',
#  'baerbock cdu',
#  'baerbock che guevara',
#  'baerbock comic']

# %%
b = suggests.get_suggests('baerbock', source='bing')
# Out:
# 2022-04-25 21:28:01,557 | 1976 | INFO | logger | bing | baerbock
# 2022-04-25 21:28:02,987 | 1976 | INFO | logger | bing | baerbock
# ...

# %%
b['suggests']
# Out:
# ['baerbock annalena',
#  'baerbock alter',
#  'baerbock aktuell',
#  'baerbock ausbildung',
#  'baerbock annalena ehemann',
#  'baerbock annalena privat',
#  'baerbock afghanistan',
#  'baerbock anne will',
#  'baerbock buch',
#  'baerbock bilder',
#  'baerbock bikini',
#  'baerbock bei putin',
#  'baerbock beine',
#  'baerbock blinken',
#  'baerbock balkan',
#  'baerbock beruf',
#  'baerbock china',
#  'baerbock cv',
#  'baerbock corona bonus',
#  'baerbock corona',
#  'baerbock cartoon',
#  'baerbock chancen',
#  'baerbock comic',
#  'baerbock corona hilfe',
#  'baerbock droht russland',
#  'baerbock dumme zitate',
#  'baerbock dienstwagen',
#  'baerbock droht',
#  'baerbock droht putin',
#  'baerbock doktorarbeit',
#  'baerbock dissertation',
#  'baerbock donbass',
#  'baerbock englisch',
#  'baerbock ehemann',
#  'baerbock english',
#  'baerbock eltern',
#  'baerbock englisch video',
#  'baerbock email',
#  'baerbock englisch youtube',
#  'baerbock eiffelturm',
# ...

# %%
tree = suggests.get_suggests_tree('baerbock', source='google', max_depth=4)
# Out:
# 2022-04-25 21:46:10,205 | 18320 | INFO | logger | google | baerbock
# 2022-04-25 21:46:11,181 | 18320 | INFO | logger | google | baerbock
# 2022-04-25 21:46:12,036 | 18320 | INFO | logger | google | baerbock
# 2022-04-25 21:46:13,052 | 18320 | INFO | logger | google | baerbock außenministerin
# 2022-04-25 21:46:14,409 | 18320 | INFO | logger | google | baerbock außenministerin
# 2022-04-25 21:46:15,470 | 18320 | INFO | logger | google | baerbock außenministerin
# 2022-04-25 21:46:16,812 | 18320 | INFO | logger | google | baerbock abgenommen
# 2022-04-25 21:46:18,139 | 18320 | INFO | logger | google | baerbock abgenommen
# 2022-04-25 21:46:19,047 | 18320 | INFO | logger | google | baerbock abgenommen
# 2022-04-25 21:46:20,097 | 18320 | INFO | logger | google | baerbock assange
# 2022-04-25 21:46:21,019 | 18320 | INFO | logger | google | baerbock assange
# 2022-04-25 21:46:22,040 | 18320 | INFO | logger | google | baerbock assange
# ...

# %%
tree
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [5], in <cell line: 1>()
# ----> 1 tree
#
# NameError: name 'tree' is not defined
